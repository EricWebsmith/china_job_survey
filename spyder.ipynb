# %%
from os import mkdir
from os import path
import re

from urllib.request import urlretrieve,urlopen
from urllib.error import HTTPError
from requests import get
from bs4 import BeautifulSoup
import threading
#from config import year, month, zhinengleibies

import gc
from contextlib import closing

# %%
from selenium import webdriver

# %%
from selenium.webdriver.chrome.options import Options
chromeOptions = Options()
chromeOptions.headless = True

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

# %%
# ?EC.element_to_be_clickable

# %%
chrome=webdriver.chrome.webdriver.WebDriver(options=chromeOptions)

# %%
chrome.get(first_page_url)

# %%
p_in=chrome.find_element_by_class_name("p_in")

# %%
p_in_td=p_in.find_element_by_class_name("td")

# %%
p_in_td.text
# Out:
# '共 37 页'

# %%
links=cd.find_elements_by_tag_name("a")

# %%
len(links)
# Out:
# 903

# %%
link = links[411]

# %%
link.tag_name
# Out:
# 'a'

# %%
link.text
# Out:
# 'JAVA开发工程师-北京\n07-31发布\n1-2万/月\n北京-海淀区 | 5-7年经验 | 本科 | 招2人\n五险一金\n年终奖金\n定期体检\n专业培训\n带薪年假\n团队活动\n员工旅游'

# %%
href=link.get_attribute("href")

# %%
href
# Out:
# 'https://jobs.51job.com/beijing-hdq/124070781.html?s=01&t=0'

# %%
link.text
# Out:
# 'JAVA开发工程师-北京\n07-31发布\n1-2万/月\n北京-海淀区 | 5-7年经验 | 本科 | 招2人\n五险一金\n年终奖金\n定期体检\n专业培训\n带薪年假\n团队活动\n员工旅游'

# %%
link.id
# Out:
# '748b7a97-d780-4f89-94ab-c51a79b4ade0'

# %%
from selenium.webdriver.support.wait import WebDriverWait

# %%
soup = BeautifulSoup(urlopen(href).read().decode('gbk'),"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>【北京-海淀区JAVA开发工程师-北京_JAVA开发工程师-北京招聘_苏州元核云技术有限公司】-前程无忧官方招聘网站</title>
# <meta content="北京-海淀区JAVA开发工程师-北京苏州元核云技术有限公司招聘，前程无忧官方网站，提供最新最全苏州元核云技术有限公司招聘职位，以及北京-海淀区JAVA开发工程师-北京相关职业信息。帮助您顺利获得北京-海淀区JAVA开发工程师-北京的职位，前程无忧招聘网站助您开启崭新职业生涯，找工作上前程无忧！" name="description"/>
# <meta content="北京-海淀区JAVA开发工程师-北京招聘,苏州元核云技术有限公司招聘,北京-海淀区JAVA开发工程师-北京最新招聘信息" name="keywords"/>
# <meta content="pc" name="applicable-device"/>
# <meta content="format=xhtml;url=https://m.51job.com/search/jobdetail.php?jobid=124070781" name="mobile-agent"/>
# <meta content="format=html5;url=https://m.51job.com/search/jobdetail.php?jobid=124070781" name="mobile-agent"/>
# <meta content="format=wml;url=https://m.51job.com/search/jobdetail.php?jobid=124070781" name="mobile-agent"/>
# ...

# %%
for link in links:
    link.
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1b1b7e7d0b7b50f58a4913835e03ed0a", element="6ce1eeee-58c9-49c1-90fc-e18b36734ad0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1b1b7e7d0b7b50f58a4913835e03ed0a", element="6d6b9081-bc2b-4b77-a98f-44bcd7e88211")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1b1b7e7d0b7b50f58a4913835e03ed0a", element="90d217ce-0d32-4aab-b08d-4c04b371316a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1b1b7e7d0b7b50f58a4913835e03ed0a", element="8921fe79-aceb-4c73-8a12-e6225592632e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1b1b7e7d0b7b50f58a4913835e03ed0a", element="e33a76b3-c7d6-4b12-9ba1-030ffce53d03")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1b1b7e7d0b7b50f58a4913835e03ed0a", element="07d0ead2-a973-488f-9e30-45299636b700")>,
# ...

# %%
first_page_url = 'https://search.51job.com/list/010000,000000,0106,00,9,99,%2520,2,1.html?lang=c&stype=&postchannel=0000&workyear=99&cotype=99&degreefrom=99&jobterm=99&companysize=99&providesalary=99&lonlat=0%2C0&radius=-1&ord_field=0&confirmdate=9&fromType=&dibiaoid=0&address=&line=&specialarea=00&from=&welfare='

# %%
soup = BeautifulSoup(urlopen(first_page_url).read().decode('gbk'),"html.parser")

# %%
soup.select_one(".p_in .td").text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-4b2cdfb0d071> in <module>
# ----> 1 soup.select_one(".p_in .td").text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
soup.select_one(".p_in").text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-b77ff031dd1c> in <module>
# ----> 1 soup.select_one(".p_in").text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>【北京,高级软件工程师招聘，求职】-前程无忧</title>
# <meta content="前程无忧为您提供最新最全的北京,高级软件工程师招聘，求职信息。网聚全国各城市的人才信息，找好工作，找好员工，上前程无忧。" name="description"/>
# <meta content="找工作,求职,人才,招聘" name="keywords"/>
# <meta content="format=html5; url=https://m.51job.com/search/joblist.php?jobarea=010000&amp;keyword=&amp;partner=webmeta" name="mobile-agent"/>
# <meta content="format=xhtml; url=https://m.51job.com/search/joblist.php?jobarea=010000&amp;keyword=&amp;partner=webmeta" name="mobile-agent"/>
# <meta content="all" name="robots"/>
# <meta content="0" http-equiv="Expires"/>
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <link href="//js.51jobcdn.com" rel="dns-prefetch"/>
# ...
