# %% [markdown]
# # Developer Salary 程序员工资调查
# 我在4月1日到3日之间，抓取了某招聘网站的软件和互联网类招聘数据40万条，其中通过程序判断为程序员的14万条。地域方面，我选择了24个主要城市。不过本文只以一线城市为研究对象。这样是为了和我2017年6月的数据做对比。
#
# 提到2017年的文章，现在居然还有很多人，把这篇文章拿出来炒作。对于社会来说，可气的是，他们直接把2017改成2019，就发表了，这不是骗人么？！对于我来说，可气的是，他们转载居然还冒充是原创，是可忍熟不可忍！

# %%
import pandas as pd
import sys
sys.path.append('..')
sys.path.append('../py')
import db
import inspect
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
import seaborn as sns
import scipy.stats as stats
import numpy as np
import weighted
# %matplotlib inline

# %%
conn=db.get_conn()
data_original=pd.read_sql(sql="select * from _201904v2 where monthly_salary>0 and monthly_salary<80000", con=conn)
conn.close()

# %%
error_job_ids=['104660258','104142922','108434795','101357291','106253516','110368302','111391233','108665401','109277048'
                  ,'73857191','108584955','102824950','102824949','111391233','110884556']
data=data_original[~data_original.job_id.isin(error_job_ids)]

# %%
#del data['publish_date']
#del data['published_on_weekend']
#del data['title']
#del data['title']
#del data['company_title']
#del data['company_description']
#del data['job_description']
#del data['job_id']

# %%
data=data.sort_values(by='headcount', ascending=False)
data.head()
# Out:
#           job_id  monthly_salary  headcount                    title career  \
# 39962  109606295          7000.0        450       网游公司招聘（游戏推广、维护、设计）  一般程序员
# 57281  110969579         12500.0        200    JAVA开发工程师（2019届应届毕业生）  一般程序员
# 24081  107281651         14000.0        200                  软件开发工程师  一般程序员
# 81560   75596794          7500.0        200                 JAVA 工程师  一般程序员
# 92461   93947364          5000.0        180  直招2018应届理工科类转行IT（零基础皆可）  一般程序员
#
#             city                                company_description  \
# 39962  guangzhou  广州川山教育是集远程高等学历教育、职业化教育、各类培训考证于一体的综合性教育机构。自成立以来...
# 57281  guangzhou  广州汇智通信技术有限公司是专业从事国家特殊通信系统研制工作的大型国有控股混合所有制企业。公司...
# 24081     dalian                            常年招聘软件架构师，开发工程师，英日双语等职位
# 81560   shenzhen  四方精创资讯有限公司（简称四方精创），是从事金融行业it综合服务和软件协同服务的高端应用软件...
# 92461    nanjing  江苏海隆是由中国知名的服务外包企业海隆软件投资成立的，海隆软件总部设于上海，注册资金3亿元，...
#
#       company_size      company_title company_type    ...      \
# 39962          50-       广州川山教育科技有限公司         民营公司    ...
# 57281    1000-5000       广州汇智通信技术有限公司           国企    ...
# 24081          50-  米斯特奥福（大连）咨询服务有限公司         民营公司    ...
# 81560    500-1000人     深圳四方精创资讯股份有限公司           合资    ...
# 92461    1000-5000       江苏海隆软件技术有限公司         民营公司    ...
#
#        pl_visual_basic  publish_date  published_on_weekend  tag_baby_care  \
# 39962            False    2019-03-13                 False          False
# 57281            False    2019-03-31                  True          False
# 24081            False    2019-04-02                 False          False
# 81560            False    2019-03-26                 False          False
# 92461            False    2019-03-19                 False          False
#
#        tag_five_insurance  tag_flexible  tag_no_overtime  tag_rest_one_day  \
# 39962               False         False            False             False
# 57281                True         False            False             False
# 24081               False         False            False             False
# 81560                True         False            False             False
# 92461                True          True            False             False
#
#        tag_rest_two_days  tag_stock
# 39962              False      False
# 57281              False      False
# 24081              False      False
# 81560              False      False
# 92461              False      False
#
# [5 rows x 90 columns]

# %%
def pd_weighted_mean(group, avg_name, weight_name):
    """ http://stackoverflow.com/questions/10951341/pandas-dataframe-aggregate-function-using-multiple-columns
    In rare instance, we may not have weights, so just return the mean. Customize this if your business case
    should return otherwise.
    """
    d = group[avg_name]
    w = group[weight_name]
    try:
        return (d * w).sum() / w.sum()
    except ZeroDivisionError:
        return d.mean()

# %% [markdown]
# # Unilateral Stats 总体统计

# %% [markdown]
# 有数据可知，程序员向一线城市集中的趋势非常明显。
#
# According to the statistics, significant amount of developers are in the first tier cities.

# %%
salary_mean=weighted.weighted_mean(data.monthly_salary.values, data.headcount.values)
q=weighted.weighted_quantile(data.monthly_salary.values,[0.025,0.25,0.5,0.75,0.975], data.headcount.values)
q
# Out:
# array([ 3750.        ,  8000.        , 12500.        , 17500.        ,
#        33333.33333333])

# %%
print('2019年中国程序员的平均工资为{:.0f}元，工资中位数为{:.0f}元，其中95%的人的工资位于{:.0f}到{:.0f}元之间。'
      .format(salary_mean, q[2], q[0], q[4]))
# Out:
# 2019年中国程序员的平均工资为13332元，工资中位数为12500元，其中95%的人的工资位于3750到33333元之间。

# %%
print('In 2019, Developers in China earn {:.0f} Yuan as average, '
      'the median is {:.0f} Yuan, 95% of them earn between {:.0f} and {:.0f} Yuan.'
      .format(salary_mean, q[2], q[0], q[4]))
# Out:
# In 2019, Developers in China earn 13332 Yuan as average, the median is 12500 Yuan, 95% of them earn between 3750 and 33333 Yuan.

# %%
data.monthly_salary.hist()

# %% [markdown]
# It does not look like normal distribution.

# %%
from scipy import stats

# %%
stats.normaltest(data.monthly_salary)
# Out:
# NormaltestResult(statistic=37529.40551233781, pvalue=0.0)

# %% [markdown]
# null hypothesis: x comes from a normal distribution
#
# p=0
#
# The null hypothesis can be rejected
#
# conclusion: data is not normally distributed.

# %% [markdown]
# Zoom in

# %%
data[data.monthly_salary<40000].monthly_salary.hist()
plt.annotate('https://github.com/juwikuang/job_survey', xy=(0,0), xytext=(2000, 100), color='white')
plt.show()

# %% [markdown]
# ## Role 角色

# %%
#Common Functions
def get_sub_stats_by_col(data, col):
    categories=data[col].unique()
    salary_mean=[]
    salary_95_min=[]
    salary_95_max=[]
    salary_median=[]

    count=[]
    
    categorys_out=[]
    for category in categories:
        #print(feature)
        idata=data[data[col]==category]
        headcount=idata.headcount.sum()
        values = idata.monthly_salary.values
        weights = idata.headcount.values
        #print(str(headcount))
        if headcount==0:
            continue
        
        salary_mean.append(np.average(values, weights=weights))
        

        q = weighted.weighted_quantile(values,[0.025,0.5,0.975],weights)
        salary_95_min.append(q[0])
        salary_median.append(q[1])
        salary_95_max.append(q[2])
        count.append(idata.headcount.sum())
        categorys_out.append(category)
    sub_data=pd.DataFrame()
    sub_data[col]=[c for c in categorys_out]
    sub_data['salary_mean']=salary_mean
    sub_data['salary_95_min']=salary_95_min
    sub_data['salary_median']=salary_median
    sub_data['salary_95_max']=salary_95_max
    sub_data['head_count']=count
    sub_data['percentage']=count/np.sum(count)
    sub_data=sub_data.sort_values(by='salary_mean', ascending=False)

    return sub_data

def get_sub_stats_by_prefix(data, prefix):
    
    features = [feature for feature in data.columns if feature.startswith(prefix)]
    salary_mean=[]
    salary_median=[]
    salary_95_min=[]
    salary_95_max=[]
    count=[]
    
    features_out=[]
    for feature in features:
        #print(feature)
        idata=data[data[feature]==1]
        headcount=idata.headcount.sum()
        values = idata.monthly_salary.values
        weights = idata.headcount.values
        #print(str(headcount))
        if headcount==0:
            continue
        
        salary_mean.append(weighted.weighted_mean(values, weights))
        q = weighted.weighted_quantile(values,[0.025,0.5,0.975],weights)
        salary_median.append(q[1])
        salary_95_min.append(q[0])
        salary_95_max.append(q[2])
        count.append(idata.headcount.sum())
        features_out.append(feature)
    sub_data=pd.DataFrame()
    sub_data['rank']=range(0,len(features_out))
    sub_data[prefix]=[f.replace(prefix,'') for f in features_out]
    sub_data['salary_mean']=salary_mean
    sub_data['salary_median']=salary_median
    sub_data['salary_95_min']=salary_95_min
    sub_data['salary_95_max']=salary_95_max
    sub_data['head_count']=count
    sub_data['percentage']=count/np.sum(count)
    sub_data=sub_data.sort_values(by='salary_mean', ascending=False)
    sub_data['rank']=range(1,len(features_out)+1)
    #sub_data=sub_data.reset_index()
    return sub_data

def apply_style(sub_data):
    return sub_data.style.hide_index().format(
        {"percentage":"{:.2%}","salary_mean":"{:.0f}","salary_median":"{:.0f}","salary_95_min":"{:.0f}","salary_95_max":"{:.0f}"})

# %%
data_career = get_sub_stats_by_col(data,'career')
apply_style(data_career)
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_21574274_6364_11e9_80ad_701ce71031ef" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >career</th>
#         <th class="col_heading level0 col1" >salary_mean</th>
#         <th class="col_heading level0 col2" >salary_95_min</th>
#         <th class="col_heading level0 col3" >salary_median</th>
#         <th class="col_heading level0 col4" >salary_95_max</th>
#         <th class="col_heading level0 col5" >head_count</th>
#         <th class="col_heading level0 col6" >percentage</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow0_col0" class="data row0 col0" >算法工程师</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow0_col1" class="data row0 col1" >19782</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow0_col2" class="data row0 col2" >4500</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow0_col3" class="data row0 col3" >17500</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow0_col4" class="data row0 col4" >45322</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow0_col5" class="data row0 col5" >26924</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow0_col6" class="data row0 col6" >7.81%</td>
#     </tr>    <tr>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow1_col0" class="data row1 col0" >系统架构师</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow1_col1" class="data row1 col1" >18373</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow1_col2" class="data row1 col2" >4250</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow1_col3" class="data row1 col3" >17500</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow1_col4" class="data row1 col4" >45000</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow1_col5" class="data row1 col5" >16074</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow1_col6" class="data row1 col6" >4.66%</td>
#     </tr>    <tr>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow2_col0" class="data row2 col0" >爬虫工程师</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow2_col1" class="data row2 col1" >13876</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow2_col2" class="data row2 col2" >3750</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow2_col3" class="data row2 col3" >12500</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow2_col4" class="data row2 col4" >27500</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow2_col5" class="data row2 col5" >625</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow2_col6" class="data row2 col6" >0.18%</td>
#     </tr>    <tr>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow3_col0" class="data row3 col0" >一般程序员</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow3_col1" class="data row3 col1" >12486</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow3_col2" class="data row3 col2" >3750</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow3_col3" class="data row3 col3" >11500</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow3_col4" class="data row3 col4" >30000</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow3_col5" class="data row3 col5" >301184</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow3_col6" class="data row3 col6" >87.32%</td>
#     </tr>    <tr>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow4_col0" class="data row4 col0" >生物信息工程师</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow4_col1" class="data row4 col1" >10189</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow4_col2" class="data row4 col2" >4500</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow4_col3" class="data row4 col3" >8333</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow4_col4" class="data row4 col4" >21792</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow4_col5" class="data row4 col5" >97</td>
#         <td id="T_21574274_6364_11e9_80ad_701ce71031efrow4_col6" class="data row4 col6" >0.03%</td>
#     </tr></tbody>
# </table>

# %%
np.sum(data.monthly_salary * data.headcount) / data.headcount.sum()
# Out:
# 13331.808271287082

# %%
data.headcount.sum()
# Out:
# 344904

# %%
data.headcount.describe()
# Out:
# count    101309.000000
# mean          3.404475
# std           4.281458
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           5.000000
# max         450.000000
# Name: headcount, dtype: float64

# %%
pd.options.display.max_columns=100
data.sort_values(by='headcount', ascending=False).head()
# Out:
#           job_id  monthly_salary  headcount                  title career  \
# 39962  109606295          7000.0        450     网游公司招聘（游戏推广、维护、设计）  一般程序员
# 24081  107281651         14000.0        200                软件开发工程师  一般程序员
# 81560   75596794          7500.0        200               JAVA 工程师  一般程序员
# 57281  110969579         12500.0        200  JAVA开发工程师（2019届应届毕业生）  一般程序员
# 92459   93944455          5000.0        180       2018届毕业生（计算机、软件）  一般程序员
#
#             city                                company_description  \
# 39962  guangzhou  广州川山教育是集远程高等学历教育、职业化教育、各类培训考证于一体的综合性教育机构。自成立以来...
# 24081     dalian                            常年招聘软件架构师，开发工程师，英日双语等职位
# 81560   shenzhen  四方精创资讯有限公司（简称四方精创），是从事金融行业it综合服务和软件协同服务的高端应用软件...
# 57281  guangzhou  广州汇智通信技术有限公司是专业从事国家特殊通信系统研制工作的大型国有控股混合所有制企业。公司...
# 92459    nanjing  江苏海隆是由中国知名的服务外包企业海隆软件投资成立的，海隆软件总部设于上海，注册资金3亿元，...
#
#       company_size      company_title company_type  ageism  db_Apache_Hive  \
# 39962          50-       广州川山教育科技有限公司         民营公司    True           False
# 24081          50-  米斯特奥福（大连）咨询服务有限公司         民营公司   False           False
# 81560    500-1000人     深圳四方精创资讯股份有限公司           合资   False           False
# 57281    1000-5000       广州汇智通信技术有限公司           国企   False           False
# 92459    1000-5000       江苏海隆软件技术有限公司         民营公司   False           False
#
#        db_CouchBase  db_CouchDB  db_DB2  db_DynamoDB  db_Elasticsearch  \
# 39962         False       False   False        False             False
# 24081         False       False   False        False             False
# 81560         False       False   False        False             False
# 57281         False       False   False        False             False
# 92459         False       False   False        False             False
#
#        db_FileMaker  db_Firebase  db_Firebird  db_Hbase  db_Informix  \
# 39962         False        False        False     False        False
# 24081         False        False        False     False        False
# 81560         False        False        False     False        False
# 57281         False        False        False     False        False
# 92459         False        False        False     False        False
#
#        db_Ingres  db_MariaDB  db_Memcached  db_MongoDB  db_MySQL  db_Neo4j  \
# 39962      False       False         False       False     False     False
# 24081      False       False         False       False     False     False
# 81560      False       False         False       False      True     False
# 57281      False       False         False       False     False     False
# 92459      False       False         False       False     False     False
#
#        db_Netezza  db_Oracle  db_PostgreSQL  db_Redis  db_Riak  db_SAP_HANA  \
# 39962       False      False          False     False    False        False
# 24081       False      False          False     False    False        False
# 81560       False       True          False     False    False        False
# 57281       False      False          False     False    False        False
# 92459       False      False          False     False    False        False
#
#        db_SQL_Server  db_SQLite  db_Solr  db_Splunk  db_Sybase  db_Teradata  \
# 39962          False      False    False      False      False        False
# 24081          False      False    False      False      False        False
# 81560          False      False    False      False      False        False
# 57281          False      False    False      False      False        False
# 92459          False      False    False      False      False        False
#
#        db_dBase edu  english experience  expert_adas  expert_blockchain  \
# 39962     False  大专    False         no        False              False
# 24081     False  本科    False        1_3        False              False
# 81560     False  本科    False        1_3        False              False
# 57281     False  本科    False         no        False              False
# 92459     False  本科     True         no        False              False
#
#        expert_embed  expert_expert  expert_gis  _996_yes  _996_no  industry  \
# 39962         False          False       False     False     True       edu
# 24081         False          False       False     False    False  computer
# 81560         False          False       False     False    False  computer
# 57281         False          False       False      True    False  computer
# 92459         False          False       False     False     True  computer
#
#        japanese                                    job_description  \
# 39962     False  月薪3500-8000底薪+补助+社保、五险一金、部分双休。部门免费包住，2.工作地点：可申...
# 24081      True  500强外企，急聘数名java软件工程师。公司福利待遇优厚。\n\n\n职能类别：\n\n\...
# 81560     False  岗位职责1.按照上级计划和安排进行技术开发工作；2. 负责金融行业应用平台后端模块开发工作；...
# 57281     False  广州汇智通信技术有限公司                                  ...
# 92459      True  职位描述：1. 从事对日大型应用软件（证券、保险、银行、交通等）系统的详细设计、开发和测试等...
#
#                                             job_summary  \
# 39962                     广州-天河区|无工作经验|大专|招450人|03-13发布
# 24081           大连-甘井子区|1年经验|本科|招200人|04-02发布|日语良好|软件工程
# 81560                          深圳|1年经验|本科|招200人|03-26发布
# 57281                         广州|无工作经验|本科|招200人|03-31发布
# 92459  南京-鼓楼区|无工作经验|本科|招180人|03-19发布|英语良好|计算机科学与技术计算机网络
#
#                                                 job_tags  phone_android  \
# 39962                                 绩效奖金,全勤奖,专业培训,节日福利          False
# 24081                                                             False
# 81560                                五险一金,专业培训,年终奖金,员工旅游          False
# 57281    五险一金,补充医疗保险,补充公积金,交通补贴,年终奖金,绩效奖金,通讯补贴,定期体检,餐饮补贴          False
# 92459  五险一金,员工旅游,交通补贴,餐饮补贴,专业培训,出国机会,绩效奖金,年终奖金,弹性工作,定期体检          False
#
#        phone_app  phone_iso  pl_c_sharp  pl_cpp  pl_delphi  pl_go  pl_haskell  \
# 39962      False      False       False   False      False  False       False
# 24081      False      False       False   False      False  False       False
# 81560      False      False       False   False      False  False       False
# 57281       True       True        True    True      False  False       False
# 92459      False      False        True    True      False  False       False
#
#        pl_java  pl_javascript  pl_julia  pl_kotlin  pl_lua  pl_matlab  \
# 39962    False          False     False      False   False      False
# 24081     True          False     False      False   False      False
# 81560     True          False     False      False   False      False
# 57281     True          False     False      False   False      False
# 92459     True          False     False      False   False      False
#
#        pl_objective_c  pl_perl  pl_php  pl_python  pl_ruby  pl_rust  \
# 39962           False    False   False      False    False    False
# 24081           False    False   False      False    False    False
# 81560           False    False   False      False    False    False
# 57281           False    False   False      False    False    False
# 92459           False    False   False      False    False    False
#
#        pl_scrala  pl_swift  pl_typescript  pl_vba  pl_visual_basic  \
# 39962      False     False          False   False            False
# 24081      False     False          False   False            False
# 81560      False     False          False   False            False
# 57281      False     False          False   False            False
# 92459      False     False          False   False            False
#
#       publish_date  published_on_weekend  tag_baby_care  tag_five_insurance  \
# 39962   2019-03-13                 False          False               False
# 24081   2019-04-02                 False          False               False
# 81560   2019-03-26                 False          False                True
# 57281   2019-03-31                  True          False                True
# 92459   2019-03-19                 False          False                True
#
#        tag_flexible  tag_no_overtime  tag_rest_one_day  tag_rest_two_days  \
# 39962         False            False             False              False
# 24081         False            False             False              False
# 81560         False            False             False              False
# 57281         False            False             False              False
# 92459          True            False             False              False
#
#        tag_stock
# 39962      False
# 24081      False
# 81560      False
# 57281      False
# 92459      False

# %% [markdown]
# # 城市

# %%
data_pl=get_sub_stats_by_col(data,'city')
apply_style(data_pl)
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_21c594a4_6364_11e9_b5f4_701ce71031ef" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >city</th>
#         <th class="col_heading level0 col1" >salary_mean</th>
#         <th class="col_heading level0 col2" >salary_95_min</th>
#         <th class="col_heading level0 col3" >salary_median</th>
#         <th class="col_heading level0 col4" >salary_95_max</th>
#         <th class="col_heading level0 col5" >head_count</th>
#         <th class="col_heading level0 col6" >percentage</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow0_col0" class="data row0 col0" >beijing</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow0_col1" class="data row0 col1" >16834</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow0_col2" class="data row0 col2" >3750</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow0_col3" class="data row0 col3" >14000</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow0_col4" class="data row0 col4" >41667</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow0_col5" class="data row0 col5" >36970</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow0_col6" class="data row0 col6" >10.72%</td>
#     </tr>    <tr>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow1_col0" class="data row1 col0" >shanghai</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow1_col1" class="data row1 col1" >16059</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow1_col2" class="data row1 col2" >5250</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow1_col3" class="data row1 col3" >14583</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow1_col4" class="data row1 col4" >35000</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow1_col5" class="data row1 col5" >58452</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow1_col6" class="data row1 col6" >16.95%</td>
#     </tr>    <tr>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow2_col0" class="data row2 col0" >shenzhen</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow2_col1" class="data row2 col1" >15763</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow2_col2" class="data row2 col2" >5250</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow2_col3" class="data row2 col3" >14000</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow2_col4" class="data row2 col4" >37500</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow2_col5" class="data row2 col5" >45981</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow2_col6" class="data row2 col6" >13.33%</td>
#     </tr>    <tr>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow3_col0" class="data row3 col0" >hangzhou</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow3_col1" class="data row3 col1" >14673</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow3_col2" class="data row3 col2" >3750</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow3_col3" class="data row3 col3" >12500</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow3_col4" class="data row3 col4" >32680</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow3_col5" class="data row3 col5" >18816</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow3_col6" class="data row3 col6" >5.46%</td>
#     </tr>    <tr>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow4_col0" class="data row4 col0" >guangzhou</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow4_col1" class="data row4 col1" >12652</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow4_col2" class="data row4 col2" >3750</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow4_col3" class="data row4 col3" >11500</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow4_col4" class="data row4 col4" >30000</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow4_col5" class="data row4 col5" >39472</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow4_col6" class="data row4 col6" >11.44%</td>
#     </tr>    <tr>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow5_col0" class="data row5 col0" >nanjing</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow5_col1" class="data row5 col1" >12544</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow5_col2" class="data row5 col2" >3750</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow5_col3" class="data row5 col3" >12000</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow5_col4" class="data row5 col4" >29406</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow5_col5" class="data row5 col5" >19588</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow5_col6" class="data row5 col6" >5.68%</td>
#     </tr>    <tr>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow6_col0" class="data row6 col0" >chengdu</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow6_col1" class="data row6 col1" >12165</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow6_col2" class="data row6 col2" >3500</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow6_col3" class="data row6 col3" >11500</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow6_col4" class="data row6 col4" >27500</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow6_col5" class="data row6 col5" >16508</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow6_col6" class="data row6 col6" >4.79%</td>
#     </tr>    <tr>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow7_col0" class="data row7 col0" >tianjin</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow7_col1" class="data row7 col1" >11592</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow7_col2" class="data row7 col2" >4500</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow7_col3" class="data row7 col3" >10000</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow7_col4" class="data row7 col4" >27500</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow7_col5" class="data row7 col5" >3063</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow7_col6" class="data row7 col6" >0.89%</td>
#     </tr>    <tr>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow8_col0" class="data row8 col0" >dongguan</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow8_col1" class="data row8 col1" >11233</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow8_col2" class="data row8 col2" >3750</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow8_col3" class="data row8 col3" >10000</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow8_col4" class="data row8 col4" >26000</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow8_col5" class="data row8 col5" >3555</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow8_col6" class="data row8 col6" >1.03%</td>
#     </tr>    <tr>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow9_col0" class="data row9 col0" >wuhan</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow9_col1" class="data row9 col1" >11028</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow9_col2" class="data row9 col2" >3750</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow9_col3" class="data row9 col3" >10000</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow9_col4" class="data row9 col4" >25000</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow9_col5" class="data row9 col5" >19591</td>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow9_col6" class="data row9 col6" >5.68%</td>
#     </tr>    <tr>
#         <td id="T_21c594a4_6364_11e9_b5f4_701ce71031efrow10_col0" class="data row10 col0" >xian</td>
#         <td id="T_21c594a4_6364_11e9_b5f

# %% [markdown]
# # 编程语言

# %%
data_pl=get_sub_stats_by_prefix(data,'pl_')
apply_style(data_pl)
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_21e2e09e_6364_11e9_97f4_701ce71031ef" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >rank</th>
#         <th class="col_heading level0 col1" >pl_</th>
#         <th class="col_heading level0 col2" >salary_mean</th>
#         <th class="col_heading level0 col3" >salary_median</th>
#         <th class="col_heading level0 col4" >salary_95_min</th>
#         <th class="col_heading level0 col5" >salary_95_max</th>
#         <th class="col_heading level0 col6" >head_count</th>
#         <th class="col_heading level0 col7" >percentage</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow0_col0" class="data row0 col0" >1</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow0_col1" class="data row0 col1" >haskell</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow0_col2" class="data row0 col2" >26621</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow0_col3" class="data row0 col3" >30000</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow0_col4" class="data row0 col4" >7806</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow0_col5" class="data row0 col5" >45000</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow0_col6" class="data row0 col6" >47</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow0_col7" class="data row0 col7" >0.01%</td>
#     </tr>    <tr>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow1_col0" class="data row1 col0" >2</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow1_col1" class="data row1 col1" >rust</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow1_col2" class="data row1 col2" >19758</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow1_col3" class="data row1 col3" >17500</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow1_col4" class="data row1 col4" >5207</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow1_col5" class="data row1 col5" >45833</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow1_col6" class="data row1 col6" >462</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow1_col7" class="data row1 col7" >0.10%</td>
#     </tr>    <tr>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow2_col0" class="data row2 col0" >3</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow2_col1" class="data row2 col1" >python</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow2_col2" class="data row2 col2" >17841</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow2_col3" class="data row2 col3" >15000</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow2_col4" class="data row2 col4" >3750</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow2_col5" class="data row2 col5" >40000</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow2_col6" class="data row2 col6" >35346</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow2_col7" class="data row2 col7" >7.49%</td>
#     </tr>    <tr>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow3_col0" class="data row3 col0" >4</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow3_col1" class="data row3 col1" >go</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow3_col2" class="data row3 col2" >17544</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow3_col3" class="data row3 col3" >15000</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow3_col4" class="data row3 col4" >5250</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow3_col5" class="data row3 col5" >40000</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow3_col6" class="data row3 col6" >31750</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow3_col7" class="data row3 col7" >6.73%</td>
#     </tr>    <tr>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow4_col0" class="data row4 col0" >5</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow4_col1" class="data row4 col1" >matlab</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow4_col2" class="data row4 col2" >17329</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow4_col3" class="data row4 col3" >16000</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow4_col4" class="data row4 col4" >4000</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow4_col5" class="data row4 col5" >37500</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow4_col6" class="data row4 col6" >6468</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow4_col7" class="data row4 col7" >1.37%</td>
#     </tr>    <tr>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow5_col0" class="data row5 col0" >6</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow5_col1" class="data row5 col1" >perl</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow5_col2" class="data row5 col2" >17250</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow5_col3" class="data row5 col3" >15000</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow5_col4" class="data row5 col4" >3750</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow5_col5" class="data row5 col5" >40000</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow5_col6" class="data row5 col6" >3270</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow5_col7" class="data row5 col7" >0.69%</td>
#     </tr>    <tr>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow6_col0" class="data row6 col0" >7</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow6_col1" class="data row6 col1" >ruby</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow6_col2" class="data row6 col2" >17129</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow6_col3" class="data row6 col3" >17500</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow6_col4" class="data row6 col4" >4143</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow6_col5" class="data row6 col5" >31562</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow6_col6" class="data row6 col6" >1640</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow6_col7" class="data row6 col7" >0.35%</td>
#     </tr>    <tr>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow7_col0" class="data row7 col0" >8</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow7_col1" class="data row7 col1" >lua</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow7_col2" class="data row7 col2" >16039</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow7_col3" class="data row7 col3" >14000</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow7_col4" class="data row7 col4" >4500</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow7_col5" class="data row7 col5" >35000</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow7_col6" class="data row7 col6" >5463</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow7_col7" class="data row7 col7" >1.16%</td>
#     </tr>    <tr>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow8_col0" class="data row8 col0" >9</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow8_col1" class="data row8 col1" >cpp</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow8_col2" class="data row8 col2" >15678</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow8_col3" class="data row8 col3" >13000</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow8_col4" class="data row8 col4" >3750</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow8_col5" class="data row8 col5" >37500</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow8_col6" class="data row8 col6" >76789</td>
#         <td id="T_21e2e09e_6364_11e9_97f4_701ce71031efrow8_col7" class="data row8 col7" >16.28%</td>

# %% [markdown]
# 数据显示，haskell才是最赚钱的编程语言。python是主流语言里面最赚钱的，比java的工资多了3000元！vb是最不赚钱的了。其中，最赚钱的编程语言和最不赚钱的，工资居然差了2倍。所以，要选好编程语言呀！

# %% [markdown]
# # 教育

# %%
data_edu=get_sub_stats_by_col(data[data.edu.isin(['大专','本科','硕士','博士'])], 'edu')
apply_style(data_edu)
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_2203d4fa_6364_11e9_94a3_701ce71031ef" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >edu</th>
#         <th class="col_heading level0 col1" >salary_mean</th>
#         <th class="col_heading level0 col2" >salary_95_min</th>
#         <th class="col_heading level0 col3" >salary_median</th>
#         <th class="col_heading level0 col4" >salary_95_max</th>
#         <th class="col_heading level0 col5" >head_count</th>
#         <th class="col_heading level0 col6" >percentage</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow0_col0" class="data row0 col0" >博士</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow0_col1" class="data row0 col1" >27090</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow0_col2" class="data row0 col2" >12321</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow0_col3" class="data row0 col3" >23667</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow0_col4" class="data row0 col4" >55000</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow0_col5" class="data row0 col5" >425</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow0_col6" class="data row0 col6" >0.15%</td>
#     </tr>    <tr>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow1_col0" class="data row1 col0" >硕士</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow1_col1" class="data row1 col1" >19920</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow1_col2" class="data row1 col2" >3833</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow1_col3" class="data row1 col3" >17500</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow1_col4" class="data row1 col4" >45000</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow1_col5" class="data row1 col5" >8406</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow1_col6" class="data row1 col6" >2.99%</td>
#     </tr>    <tr>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow2_col0" class="data row2 col0" >本科</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow2_col1" class="data row2 col1" >14697</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow2_col2" class="data row2 col2" >4000</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow2_col3" class="data row2 col3" >12500</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow2_col4" class="data row2 col4" >35000</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow2_col5" class="data row2 col5" >172776</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow2_col6" class="data row2 col6" >61.50%</td>
#     </tr>    <tr>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow3_col0" class="data row3 col0" >大专</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow3_col1" class="data row3 col1" >10804</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow3_col2" class="data row3 col2" >3750</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow3_col3" class="data row3 col3" >9500</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow3_col4" class="data row3 col4" >23500</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow3_col5" class="data row3 col5" >99317</td>
#         <td id="T_2203d4fa_6364_11e9_94a3_701ce71031efrow3_col6" class="data row3 col6" >35.35%</td>
#     </tr></tbody>
# </table>

# %%
salary_associate=data[data.edu=='大专'].monthly_salary
salary_bachelor=data[data.edu=='本科'].monthly_salary
salary_master=data[data.edu=='硕士'].monthly_salary
salary_phd=data[data.edu=='博士'].monthly_salary

# %%
print('大专，本科，硕士，博士的平均工资分别是{:.0f}，{:.0f}，{:.0f}，{:.0f}。中位数分别是{:.0f}， {:.0f}，{:.0f}， {:.0f}。'.format(
    salary_associate.mean(),salary_bachelor.mean(),salary_master.mean(),salary_phd.mean(),
    salary_associate.median(),salary_bachelor.median(),salary_master.median(),salary_phd.median()))
# Out:
# 大专，本科，硕士，博士的平均工资分别是11108，15046，20261，27971。中位数分别是10000， 12500，18000， 25000。

# %%
stats.f_oneway(salary_phd, salary_master)
# Out:
# F_onewayResult(statistic=73.94325816418217, pvalue=1.284824828320451e-17)

# %%
stats.f_oneway(salary_master, salary_bachelor)
# Out:
# F_onewayResult(statistic=1169.3344687888964, pvalue=1.4385635263166155e-253)

# %%
stats.f_oneway(salary_bachelor, salary_associate)
# Out:
# F_onewayResult(statistic=5956.12615859069, pvalue=0.0)

# %% [markdown]
# 经过Oneway Anova Test，证明从大专到博士，学历每提高一级，工资都有显著的提高。

# %%
order=['大专','本科','硕士','博士']
a=sns.boxplot(y='edu',x='monthly_salary',order=order,data=data[data.edu.isin(order)], orient='h')
plt.annotate('https://github.com/juwikuang/job_survey', xy=(0.5,1.5), xytext=(2, 1.55))
plt.show()

# %% [markdown]
# # 工作经验 Working Experience

# %%
data_experience=get_sub_stats_by_col(data, 'experience')
apply_style(data_experience)
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_2259e510_6364_11e9_afb1_701ce71031ef" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >experience</th>
#         <th class="col_heading level0 col1" >salary_mean</th>
#         <th class="col_heading level0 col2" >salary_95_min</th>
#         <th class="col_heading level0 col3" >salary_median</th>
#         <th class="col_heading level0 col4" >salary_95_max</th>
#         <th class="col_heading level0 col5" >head_count</th>
#         <th class="col_heading level0 col6" >percentage</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow0_col0" class="data row0 col0" >10+</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow0_col1" class="data row0 col1" >29024</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow0_col2" class="data row0 col2" >12057</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow0_col3" class="data row0 col3" >27500</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow0_col4" class="data row0 col4" >54167</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow0_col5" class="data row0 col5" >678</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow0_col6" class="data row0 col6" >0.20%</td>
#     </tr>    <tr>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow1_col0" class="data row1 col0" >5_10</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow1_col1" class="data row1 col1" >20264</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow1_col2" class="data row1 col2" >9000</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow1_col3" class="data row1 col3" >18500</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow1_col4" class="data row1 col4" >41667</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow1_col5" class="data row1 col5" >33826</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow1_col6" class="data row1 col6" >9.81%</td>
#     </tr>    <tr>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow2_col0" class="data row2 col0" >3_5</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow2_col1" class="data row2 col1" >15375</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow2_col2" class="data row2 col2" >7000</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow2_col3" class="data row2 col3" >13000</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow2_col4" class="data row2 col4" >37500</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow2_col5" class="data row2 col5" >91667</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow2_col6" class="data row2 col6" >26.58%</td>
#     </tr>    <tr>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow3_col0" class="data row3 col0" >1_3</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow3_col1" class="data row3 col1" >11504</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow3_col2" class="data row3 col2" >5000</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow3_col3" class="data row3 col3" >10417</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow3_col4" class="data row3 col4" >27500</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow3_col5" class="data row3 col5" >101572</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow3_col6" class="data row3 col6" >29.45%</td>
#     </tr>    <tr>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow4_col0" class="data row4 col0" >no</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow4_col1" class="data row4 col1" >11225</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow4_col2" class="data row4 col2" >2500</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow4_col3" class="data row4 col3" >9000</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow4_col4" class="data row4 col4" >30000</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow4_col5" class="data row4 col5" >117161</td>
#         <td id="T_2259e510_6364_11e9_afb1_701ce71031efrow4_col6" class="data row4 col6" >33.97%</td>
#     </tr></tbody>
# </table>

# %%
salary_we_10=data[data.experience=='10+'].monthly_salary
salary_we_5_10=data[data.experience=='5_10'].monthly_salary
salary_we_3_5=data[data.experience=='3_5'].monthly_salary
salary_we_1_3=data[data.experience=='1_3'].monthly_salary
salary_we_no=data[data.experience=='no'].monthly_salary

# %%
order=['10+','5_10','3_5','1_3']
sns.boxplot(y='experience',x='monthly_salary',order=order,data=data[data.experience.isin(order)], orient='h')
plt.annotate('https://github.com/juwikuang/job_survey', xy=(1.5,1.5), xytext=(1.55, 1.55))
plt.show()

# %% [markdown]
# # 公司 Company

# %% [markdown]
# ## 公司性质 Company Type

# %%
data_company_type=get_sub_stats_by_col(data,'company_type')
apply_style(data_company_type)
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_22bf36e6_6364_11e9_b0cc_701ce71031ef" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >company_type</th>
#         <th class="col_heading level0 col1" >salary_mean</th>
#         <th class="col_heading level0 col2" >salary_95_min</th>
#         <th class="col_heading level0 col3" >salary_median</th>
#         <th class="col_heading level0 col4" >salary_95_max</th>
#         <th class="col_heading level0 col5" >head_count</th>
#         <th class="col_heading level0 col6" >percentage</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow0_col0" class="data row0 col0" >外资（欧美）</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow0_col1" class="data row0 col1" >16536</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow0_col2" class="data row0 col2" >3750</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow0_col3" class="data row0 col3" >15000</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow0_col4" class="data row0 col4" >37500</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow0_col5" class="data row0 col5" >14480</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow0_col6" class="data row0 col6" >4.20%</td>
#     </tr>    <tr>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow1_col0" class="data row1 col0" >外企代表处</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow1_col1" class="data row1 col1" >15233</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow1_col2" class="data row1 col2" >2500</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow1_col3" class="data row1 col3" >13539</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow1_col4" class="data row1 col4" >35000</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow1_col5" class="data row1 col5" >258</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow1_col6" class="data row1 col6" >0.07%</td>
#     </tr>    <tr>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow2_col0" class="data row2 col0" >合资</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow2_col1" class="data row2 col1" >14608</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow2_col2" class="data row2 col2" >3750</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow2_col3" class="data row2 col3" >12500</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow2_col4" class="data row2 col4" >31667</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow2_col5" class="data row2 col5" >28019</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow2_col6" class="data row2 col6" >8.12%</td>
#     </tr>    <tr>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow3_col0" class="data row3 col0" >外资（非欧美）</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow3_col1" class="data row3 col1" >13485</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow3_col2" class="data row3 col2" >3750</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow3_col3" class="data row3 col3" >12500</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow3_col4" class="data row3 col4" >30000</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow3_col5" class="data row3 col5" >17375</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow3_col6" class="data row3 col6" >5.04%</td>
#     </tr>    <tr>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow4_col0" class="data row4 col0" >国企</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow4_col1" class="data row4 col1" >13228</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow4_col2" class="data row4 col2" >4275</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow4_col3" class="data row4 col3" >12500</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow4_col4" class="data row4 col4" >27500</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow4_col5" class="data row4 col5" >22448</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow4_col6" class="data row4 col6" >6.51%</td>
#     </tr>    <tr>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow5_col0" class="data row5 col0" >民营公司</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow5_col1" class="data row5 col1" >13024</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow5_col2" class="data row5 col2" >3750</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow5_col3" class="data row5 col3" >11500</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow5_col4" class="data row5 col4" >34583</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow5_col5" class="data row5 col5" >259549</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow5_col6" class="data row5 col6" >75.25%</td>
#     </tr>    <tr>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow6_col0" class="data row6 col0" >事业单位</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow6_col1" class="data row6 col1" >12897</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow6_col2" class="data row6 col2" >5227</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow6_col3" class="data row6 col3" >11500</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow6_col4" class="data row6 col4" >29167</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow6_col5" class="data row6 col5" >2270</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow6_col6" class="data row6 col6" >0.66%</td>
#     </tr>    <tr>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow7_col0" class="data row7 col0" >非营利组织</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow7_col1" class="data row7 col1" >9366</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow7_col2" class="data row7 col2" >3250</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow7_col3" class="data row7 col3" >9000</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow7_col4" class="data row7 col4" >21508</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow7_col5" class="data row7 col5" >299</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow7_col6" class="data row7 col6" >0.09%</td>
#     </tr>    <tr>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow8_col0" class="data row8 col0" >政府机关</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow8_col1" class="data row8 col1" >9132</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow8_col2" class="data row8 col2" >5250</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow8_col3" class="data row8 col3" >7000</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow8_col4" class="data row8 col4" >20833</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow8_col5" class="data row8 col5" >206</td>
#         <td id="T_22bf36e6_6364_11e9_b0cc_701ce71031efrow8_col6" class="data row8 col6" >0.06%</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# us_eu是欧美外企，startup是创业公司，listed是上市公司，state是国企，private是私企，foreign是非欧美外企，其他不足1000个样本的不管了。

# %% [markdown]
# ## 公司规模 Company Size

# %%
data_company_size=get_sub_stats_by_col(data,'company_size')
apply_style(data_company_size)
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_22e24eee_6364_11e9_8b9f_701ce71031ef" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >company_size</th>
#         <th class="col_heading level0 col1" >salary_mean</th>
#         <th class="col_heading level0 col2" >salary_95_min</th>
#         <th class="col_heading level0 col3" >salary_median</th>
#         <th class="col_heading level0 col4" >salary_95_max</th>
#         <th class="col_heading level0 col5" >head_count</th>
#         <th class="col_heading level0 col6" >percentage</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow0_col0" class="data row0 col0" >10000+</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow0_col1" class="data row0 col1" >20527</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow0_col2" class="data row0 col2" >4500</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow0_col3" class="data row0 col3" >17500</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow0_col4" class="data row0 col4" >45000</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow0_col5" class="data row0 col5" >16413</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow0_col6" class="data row0 col6" >4.76%</td>
#     </tr>    <tr>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow1_col0" class="data row1 col0" >5000-10000</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow1_col1" class="data row1 col1" >14470</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow1_col2" class="data row1 col2" >3000</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow1_col3" class="data row1 col3" >13000</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow1_col4" class="data row1 col4" >30000</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow1_col5" class="data row1 col5" >6558</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow1_col6" class="data row1 col6" >1.90%</td>
#     </tr>    <tr>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow2_col0" class="data row2 col0" >500-1000人</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow2_col1" class="data row2 col1" >14366</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow2_col2" class="data row2 col2" >3934</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow2_col3" class="data row2 col3" >12500</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow2_col4" class="data row2 col4" >35000</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow2_col5" class="data row2 col5" >34462</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow2_col6" class="data row2 col6" >9.99%</td>
#     </tr>    <tr>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow3_col0" class="data row3 col0" >1000-5000</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow3_col1" class="data row3 col1" >14242</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow3_col2" class="data row3 col2" >4500</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow3_col3" class="data row3 col3" >12500</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow3_col4" class="data row3 col4" >34000</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow3_col5" class="data row3 col5" >38616</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow3_col6" class="data row3 col6" >11.20%</td>
#     </tr>    <tr>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow4_col0" class="data row4 col0" >150-500</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow4_col1" class="data row4 col1" >13036</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow4_col2" class="data row4 col2" >3750</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow4_col3" class="data row4 col3" >12500</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow4_col4" class="data row4 col4" >30000</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow4_col5" class="data row4 col5" >76862</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow4_col6" class="data row4 col6" >22.29%</td>
#     </tr>    <tr>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow5_col0" class="data row5 col0" ></td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow5_col1" class="data row5 col1" >12922</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow5_col2" class="data row5 col2" >3750</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow5_col3" class="data row5 col3" >9000</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow5_col4" class="data row5 col4" >43125</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow5_col5" class="data row5 col5" >1850</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow5_col6" class="data row5 col6" >0.54%</td>
#     </tr>    <tr>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow6_col0" class="data row6 col0" >50-150</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow6_col1" class="data row6 col1" >12365</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow6_col2" class="data row6 col2" >3750</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow6_col3" class="data row6 col3" >11500</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow6_col4" class="data row6 col4" >30000</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow6_col5" class="data row6 col5" >107905</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow6_col6" class="data row6 col6" >31.29%</td>
#     </tr>    <tr>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow7_col0" class="data row7 col0" >50-</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow7_col1" class="data row7 col1" >12230</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow7_col2" class="data row7 col2" >3750</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow7_col3" class="data row7 col3" >11500</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow7_col4" class="data row7 col4" >27500</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow7_col5" class="data row7 col5" >62238</td>
#         <td id="T_22e24eee_6364_11e9_8b9f_701ce71031efrow7_col6" class="data row7 col6" >18.05%</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# 公司越大，工资越高

# %% [markdown]
# ## 行业 Industry

# %%
data_industry=get_sub_stats_by_col(data,'industry')
apply_style(data_industry)
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_230f519c_6364_11e9_a384_701ce71031ef" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >industry</th>
#         <th class="col_heading level0 col1" >salary_mean</th>
#         <th class="col_heading level0 col2" >salary_95_min</th>
#         <th class="col_heading level0 col3" >salary_median</th>
#         <th class="col_heading level0 col4" >salary_95_max</th>
#         <th class="col_heading level0 col5" >head_count</th>
#         <th class="col_heading level0 col6" >percentage</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow0_col0" class="data row0 col0" >finance</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow0_col1" class="data row0 col1" >15362</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow0_col2" class="data row0 col2" >4500</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow0_col3" class="data row0 col3" >13500</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow0_col4" class="data row0 col4" >31345</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow0_col5" class="data row0 col5" >9384</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow0_col6" class="data row0 col6" >2.72%</td>
#     </tr>    <tr>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow1_col0" class="data row1 col0" >logistic</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow1_col1" class="data row1 col1" >13911</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow1_col2" class="data row1 col2" >4750</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow1_col3" class="data row1 col3" >12500</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow1_col4" class="data row1 col4" >32500</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow1_col5" class="data row1 col5" >3393</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow1_col6" class="data row1 col6" >0.98%</td>
#     </tr>    <tr>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow2_col0" class="data row2 col0" >edu</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow2_col1" class="data row2 col1" >13886</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow2_col2" class="data row2 col2" >3750</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow2_col3" class="data row2 col3" >12500</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow2_col4" class="data row2 col4" >35000</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow2_col5" class="data row2 col5" >19224</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow2_col6" class="data row2 col6" >5.57%</td>
#     </tr>    <tr>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow3_col0" class="data row3 col0" >service</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow3_col1" class="data row3 col1" >13638</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow3_col2" class="data row3 col2" >4500</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow3_col3" class="data row3 col3" >12500</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow3_col4" class="data row3 col4" >35000</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow3_col5" class="data row3 col5" >2152</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow3_col6" class="data row3 col6" >0.62%</td>
#     </tr>    <tr>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow4_col0" class="data row4 col0" >trade</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow4_col1" class="data row4 col1" >13381</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow4_col2" class="data row4 col2" >3750</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow4_col3" class="data row4 col3" >12500</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow4_col4" class="data row4 col4" >30000</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow4_col5" class="data row4 col5" >16798</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow4_col6" class="data row4 col6" >4.87%</td>
#     </tr>    <tr>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow5_col0" class="data row5 col0" >computer</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow5_col1" class="data row5 col1" >13297</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow5_col2" class="data row5 col2" >3750</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow5_col3" class="data row5 col3" >12500</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow5_col4" class="data row5 col4" >33666</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow5_col5" class="data row5 col5" >270157</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow5_col6" class="data row5 col6" >78.33%</td>
#     </tr>    <tr>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow6_col0" class="data row6 col0" >gov</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow6_col1" class="data row6 col1" >12604</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow6_col2" class="data row6 col2" >3750</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow6_col3" class="data row6 col3" >11500</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow6_col4" class="data row6 col4" >30000</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow6_col5" class="data row6 col5" >4297</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow6_col6" class="data row6 col6" >1.25%</td>
#     </tr>    <tr>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow7_col0" class="data row7 col0" >medical</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow7_col1" class="data row7 col1" >12524</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow7_col2" class="data row7 col2" >4500</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow7_col3" class="data row7 col3" >11500</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow7_col4" class="data row7 col4" >27500</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow7_col5" class="data row7 col5" >6574</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow7_col6" class="data row7 col6" >1.91%</td>
#     </tr>    <tr>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow8_col0" class="data row8 col0" >realestate</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow8_col1" class="data row8 col1" >12335</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow8_col2" class="data row8 col2" >3750</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow8_col3" class="data row8 col3" >11500</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow8_col4" class="data row8 col4" >30000</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow8_col5" class="data row8 col5" >4313</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow8_col6" class="data row8 col6" >1.25%</td>
#     </tr>    <tr>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow9_col0" class="data row9 col0" ></td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow9_col1" class="data row9 col1" >12125</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow9_col2" class="data row9 col2" >6500</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow9_col3" class="data row9 col3" >12714</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow9_col4" class="data row9 col4" >14000</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow9_col5" class="data row9 col5" >8</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow9_col6" class="data row9 col6" >0.00%</td>
#     </tr>    <tr>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow10_col0" class="data row10 col0" >ads</td>
#         <td id="T_230f519c_6364_11e9_a384_701ce71031efrow10_col
