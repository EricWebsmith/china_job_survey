# %%
from config import *

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['Microsoft YaHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
import seaborn as sns
import scipy.stats as stats
import numpy as np

# %matplotlib inline

# %%
print(f'{year}年{month}月')
# Out:
# 2020年10月

# %%
import pandas as pd
pd.set_option('display.max_rows', 200)
import matplotlib.pyplot as plt
import sys
sys.path.append('../../py')
import db

# %%
conn=db.get_conn()

# %%
stat_data = pd.read_sql(sql='select * from general_stats order by year_month', con=conn)
stat_data
# Out:
#    year_month  salary_mean  salary_median  jd_count  head_count
# 0      202001        13800          12500     84978      271479
# 1      202002        14379          12500     79887      247850
# 2      202003        14514          12500     74063      228240
# 3      202004        14506          12500     97825      295541
# 4      202005        14488          12500    102002      309115
# 5      202006        14370          12500    103149      310619
# 6      202007        14415          12500     96986      288685
# 7      202008        14401          12500    117866      346036
# 8      202009        14469          12500    119174      352733
# 9      202010        14552          12500    121263      359058

# %%
stat_data['year_month'] = stat_data['year_month'] - 202000

# %%
plt.figure(figsize=(10,6))
plt.plot("year_month","salary_mean",data=stat_data)
plt.title(f"{year}年月程序员收入按月变化")
plt.xlabel("月")
plt.ylabel("工资")
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot("year_month","jd_count",data=stat_data)
plt.show()

# %% [markdown]
# # 按照职能统计平均工资

# %%
data_original=pd.read_sql(sql=f"select * from jobs where year_month={year}{month:02} and monthly_salary>0 and monthly_salary<100000", con=db.get_conn())

data_career=data_original.groupby(by='career').agg(
    salary=pd.NamedAgg(column='monthly_salary', aggfunc='mean')
)

data_career['salary']=data_career['salary'].astype(int)

data_career[f'2020年{month}月']=data_career['salary']
del data_career['salary']

# %%
data_original['monthly_salary'].hist()
plt.xlabel("工资")
plt.ylabel("人数")
plt.title("工资人数分布")
# Out:
# Text(0.5, 1.0, '工资人数分布')

# %%
data_original2019=pd.read_sql(sql=f"select * from jobs where year_month={year}{3:02} and monthly_salary>0 and monthly_salary<100000", con=db.get_conn())

data_career2019=data_original2019.groupby(by='career').agg(
    salary=pd.NamedAgg(column='monthly_salary', aggfunc='mean')
)

data_career2019[f'{year}年{1}月']=data_career2019['salary'].astype(int)
del data_career2019['salary']

# %%
data_career2019.join(data_career, how='outer')
# Out:
#                 2020年1月  2020年10月
# career
# ADAS            20092.0     17510
# Android开发工程师    13487.0     14511
# BI工程师               NaN     13658
# CAE             16263.0     15355
# CTO             41491.0     35916
# Cocos2d-x开发工程师  16572.0     16010
# DSP             17554.0     17302
# ETL             13595.0     13514
# ETL开发工程师            NaN     13163
# GIS             12880.0     12596
# HTML5开发工程师          NaN     13334
# Hadoop工程师       17791.0     16850
# MES             12367.0     12498
# SLAM            17020.0     23500
# Unity3D         13931.0     15236
# Unity3d开发工程师        NaN     17360
# Web前端开发             NaN     12633
# iOS开发工程师            NaN     14804
# 人工智能            20025.0     19910
# 信号处理            14178.0     15009
# 分布式             18678.0     19985
# 前端开发                NaN     12709
# 区块链开发           20325.0     19898
# 反作弊算法工程师        40500.0     37500
# 图像处理工程师         16518.0     16562
# 图像算法工程师         20178.0     19571
# 图像识别工程师             NaN     14769
# 大数据             16402.0     16633
# 大数据开发工程师            NaN     14964
# 小程序开发工程师            NaN     10955
# 嵌入式软件开发         17329.0     14469
# 技术主管            18321.0     17555
# 推荐算法工程师         34215.0     29880
# 搜索算法工程师         35795.0     32500
# 敏捷教练            26272.0     25000
# 数据                  NaN      8741
# 数据仓库工程师             NaN     14859
# 数据分析师               NaN     10655
# 数据分析经理主管            NaN     13903
# 数据建模工程师             NaN     14685
# 数据治理工程师             NaN     13020
# 数据科学家           29150.0     28170
# 数据采集工程师             NaN      8679
# 机器人             15356.0     15480
# 机器学习            22256.0     19433
# 机器视觉工程师         13764.0     12933
# 架构师             25771.0     27018
# 深度学习工程师         23118.0     20792
# 游戏客户端开发工程师          NaN     16853
# 游戏开发工程师             NaN     17133
# 游戏服务端开发工程师          NaN     17744
# 爬虫开发工程师         13203.0     13523
# 生物信息            11833.0     13380
# 移动开发工程师             NaN     14274
# 算法工程师           19828.0     20313
# 系统分析员               NaN     12051
# 系统架构设计师         18635.0     19316
# 编译器开发工程师        23566.0     25217
# 网站架构设计师         14563.0     10249
# 自然语言处理（NLP）     23959.0     24048
# 芯片              26946.0     28295
# 视觉软件工程师         14835.0     14968
# 语音识别工程师             NaN     15207
# 软件工程师           13497.0     13798
# 遥感              13411.0     12438
# 驱动工程师           17891.0     18169

# %%
data_original2019
# Out:
#           job_id  year_month  monthly_salary  headcount  \
# 0      100004606      202003           14000          5
# 1      100007823      202003           12500          5
# 2      100008460      202003           15000         12
# 3      100011882      202003           11000          1
# 4      100015281      202003           12500          3
# ...          ...         ...             ...        ...
# 73673   99997289      202003           17500          5
# 73674   99997652      202003           13000          2
# 73675   99998962      202003           12500          3
# 73676   99999731      202003           12500          1
# 73677   99999880      202003           22500          4
#
#                             title  \
# 0             Linux C/C++ 高级研发工程师
# 1                      ABAP开发 工程师
# 2      java高级工程师(YC) (职位编号：YC001)
# 3                       Java开发工程师
# 4                     Nodejs开发工程师
# ...                           ...
# 73673                       算法工程师
# 73674                Android开发工程师
# 73675                   java开发工程师
# 73676                  Labview工程师
# 73677                 Java高级开发工程师
#
#                                               page_title zhinengleibie  \
# 0      【上海-浦东新区Linux C/C++ 高级研发工程师_Linux C/C++ 高级研发工程...         软件工程师
# 1      【深圳-宝安区ABAP开发 工程师_ABAP开发 工程师招聘_深圳市合元科技有限公司】-前程...         软件工程师
# 2      【南京-江宁区java高级工程师(YC)_java高级工程师(YC)招聘_南京新联软件有限责...         软件工程师
# 3      【北京Java开发工程师_Java开发工程师招聘_上海英方软件股份有限公司】-前程无忧官方招聘网站         软件工程师
# 4      【大连Nodejs开发工程师_Nodejs开发工程师招聘_英诺瑞新科技发展（大连）有限公司】...         软件工程师
# ...                                                  ...           ...
# 73673          【杭州算法工程师_算法工程师招聘_杭州诚智天扬科技有限公司】-前程无忧官方招聘网站         算法工程师
# 73674  【深圳-宝安区Android开发工程师_Android开发工程师招聘_深圳市发掘科技有限公司...         软件工程师
# 73675  【成都-武侯区java开发工程师_java开发工程师招聘_广州思迈特软件有限公司】-前程无忧...         软件工程师
# 73676  【苏州-吴中区Labview工程师_Labview工程师招聘_苏州固特伟自动化系统设备有限公...         软件工程师
# 73677  【深圳Java高级开发工程师_Java高级开发工程师招聘_印力商用置业有限公司】-前程无忧官...         软件工程师
#
#              career city province  ... bd_hbase  bd_storm  bd_pig  bd_mahout  \
# 0             软件工程师   上海       上海  ...    False     False   False      False
# 1             软件工程师   深圳       广东  ...    False     False   False      False
# 2             软件工程师   南京       江苏  ...    False     False   False      False
# 3             软件工程师   北京       北京  ...     True     False   False      False
# 4             软件工程师   大连       辽宁  ...    False     False   False      False
# ...             ...  ...      ...  ...      ...       ...     ...        ...
# 73673         算法工程师   杭州       浙江  ...    False     False   False      False
# 73674  Android开发工程师   深圳       广东  ...    False     False   False      False
# 73675         软件工程师   成都       四川  ...    False     False   False      False
# 73676         软件工程师   苏州       江苏  ...    False     False   False      False
# 73677         软件工程师   深圳       广东  ...    False     False   False      False
#
#        bd_impala  bd_yarn  bd_alluxio  bd_flink  bd_presto  bd_heron
# 0          False    False       False     False      False     False
# 1          False    False       False     False      False     False
# 2          False    False       False     False      False     False
# 3          False    False       False     False      False     False
# 4          False    False       False     False      False     False
# ...          ...      ...         ...       ...        ...       ...
# 73673      False    False       False     False      False     False
# 73674      False    False       False     False      False     False
# 73675      False    False       False     False      False     False
# 73676      False    False       False     False      False     False
# 73677      False    False       False     False      False     False
#
# [73678 rows x 118 columns]

# %%
salary=data_original.monthly_salary.values

# %%
salary.sort()

# %%
data_original[data_original['monthly_salary'].isna()]
# Out:
# Empty DataFrame
# Columns: [job_id, year_month, monthly_salary, headcount, title, page_title, zhinengleibie, career, city, province, company_id, ageism, db_Apache_Hive, db_CouchBase, db_CouchDB, db_DB2, db_DynamoDB, db_Elasticsearch, db_FileMaker, db_Firebase, db_Firebird, db_Hbase, db_Informix, db_Ingres, db_MariaDB, db_Memcached, db_MongoDB, db_MySQL, db_Neo4j, db_Netezza, db_Oracle, db_PostgreSQL, db_Redis, db_Riak, db_SAP_HANA, db_SQL_Server, db_SQLite, db_Solr, db_Splunk, db_Sybase, db_Teradata, db_dBase, edu, experience, expert_adas, expert_blockchain, expert_embed, expert_expert, expert_gis, _996_yes, _996_no, lang_english, lang_japanese, job_description, job_summary, job_tags, phone_android, phone_app, phone_iso, pl_c_sharp, pl_cpp, pl_delphi, pl_go, pl_haskell, pl_java, pl_javascript, pl_julia, pl_kotlin, pl_lua, pl_matlab, pl_objective_c, pl_perl, pl_php, pl_python, pl_ruby, pl_rust, pl_swift, pl_typescript, pl_vba, pl_visual_basic, pl_r, pl_scala, publish_date, published_on_weekend, tag_baby_care, tag_five_insurance, tag_flexible, tag_no_overtime, tag_rest_one_day, tag_rest_two_days, tag_stock, ml_pytorch, ml_tensorflow, ml_caffe, ml_cntk, ml_chainer, ml_mxnet, ml_keras, ml_deeplearning4j, ml_theano, ...]
# Index: []
#
# [0 rows x 118 columns]

# %%
import numpy as np

# %%
def lorenz_curve(X):
    X_lorenz = X.cumsum() / X.sum()
    X_lorenz = np.insert(X_lorenz, 0, 0) 
    X_lorenz[0], X_lorenz[-1]
    fig, ax = plt.subplots(figsize=[6,6])
    ## scatter plot of Lorenz curve
    ax.scatter(np.arange(X_lorenz.size)/(X_lorenz.size-1), X_lorenz, 
               color='darkgreen', s=1)
    ## line plot of equality
    ax.plot([0,1], [0,1], color='k')
    ax.set_xlabel("累计人群")
    ax.set_ylabel("累计收入")
    ax.set_title("洛伦茨曲线")

# %%
lorenz_curve(salary)

# %%
def gini(arr):
    ## first sort
    sorted_arr = arr.copy()
    sorted_arr.sort()
    n = arr.size
    coef_ = 2. / n
    const_ = (n + 1.) / n
    weighted_sum = sum([(i+1)*yi for i, yi in enumerate(sorted_arr)])
    return coef_*weighted_sum/(sorted_arr.sum()) - const_

# %%
gini(salary)
# Out:
# 0.2567986036764407

# %%
len(salary)
# Out:
# 121300

# %%
city_salary=data_original.loc[data_original['city']=='北京'].monthly_salary.values
display(gini(city_salary))
display(lorenz_curve(city_salary))
# Out:
# 0.23126937829161442
# None

# %%
city_salary=data_original.loc[data_original['city']=='杭州'].monthly_salary.values
display(gini(city_salary))
display(lorenz_curve(city_salary))
# Out:
# 0.25761606393622527
# None
